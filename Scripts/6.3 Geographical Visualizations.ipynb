# %% [markdown]
# # 6.3: Geographical Visualizations with Python

# %% [markdown]
# # Table of Contents

# %% [markdown]
# [01. Importing Libraries](#01.-Importing-Libraries)

# %% [markdown]
# [02. Importing Data](#02.-Importing-Data)

# %% [markdown]
# [03. Creating a choropleth map](#03.-Creating-a-choropleth-map)

# %% [markdown]
# [04. Key Questions & Answers](#04.-Key-Questions-&-Answers)

# %% [markdown]
# ## 01. Importing Libraries

# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
# This command propts matplotlib visuals to appear in the notebook 
# %matplotlib inline

# %% [markdown]
# # 02. Importing Data

# %%
# Import Divvy_trip dataset

df = pd.read_pickle( r'E:\Careerfoundry course\My Project\Generated Data\Divvy_cleaned.pkl')

# %%
df.head()
# Out:
#    trip_id          start_time            end_time bike_id  trip_duration  \
# 0  8546790 2015-12-31 17:35:00 2015-12-31 17:44:00     979            521
# 1  8546793 2015-12-31 17:37:00 2015-12-31 17:41:00    1932            256
# 2  8546795 2015-12-31 17:37:00 2015-12-31 17:40:00    1693            134
# 3  8546797 2015-12-31 17:38:00 2015-12-31 17:55:00    3370            995
# 4  8546798 2015-12-31 17:38:00 2015-12-31 17:41:00    2563            177
#
#   from_station_id           from_station_name to_station_id  \
# 0             117    Wilton Ave & Belmont Ave           229
# 1             301      Clark St & Schiller St           138
# 2             465      Marine Dr & Ainslie St           251
# 3             333  Ashland Ave & Blackhawk St           198
# 4              48  Larrabee St & Kingsbury St           111
#
#                       to_station_name   user_type  ... to_latitude  \
# 0           Southport Ave & Roscoe St  Subscriber  ...   41.943739
# 1          Clybourn Ave & Division St  Subscriber  ...   41.904613
# 2          Clarendon Ave & Leland Ave  Subscriber  ...   41.967968
# 3  Green St (Halsted St) & Madison St  Subscriber  ...   41.881892
# 4              Sedgwick St & Huron St  Subscriber  ...   41.894666
#
#    to_longitude                   to_location  year month_start  month_end  \
# 0    -87.664020   POINT (-87.66402 41.943739)  2015          12         12
# 1    -87.640552  POINT (-87.640552 41.904613)  2015          12         12
# 2    -87.650001  POINT (-87.650001 41.967968)  2015          12         12
# 3    -87.648789  POINT (-87.648789 41.881892)  2015          12         12
# 4    -87.638437  POINT (-87.638437 41.894666)  2015          12         12
#
#         day hour_start  hour_end  age
# 0  Thursday         17        17   24
# 1  Thursday         17        17   23
# 2  Thursday         17        17   28
# 3  Thursday         17        17   40
# 4  Thursday         17        17   25
#
# [5 rows x 25 columns]

# %% [markdown]
# # 03. Creating a choropleth map

# %%
# Group the data by starting station latitude and longitude and count the number of trips
trip_counts1 = df.groupby(['from_latitude', 'from_longitude']).size().reset_index(name='trip_count')

# Display the top 5 rows of the aggregated data
print(trip_counts1.head())
# Out:
#    from_latitude  from_longitude  trip_count
# 0      41.736646      -87.622634         269
# 1      41.743116      -87.614800         353
# 2      41.743316      -87.622849         182
# 3      41.743441      -87.604836          83
# 4      41.743921      -87.575225         124

# %%
# Create a base map centered on Chicago (assuming Divvy is Chicago-based)
m1 = folium.Map(location=[41.8781, -87.6298], zoom_start=12)

# Add the trip count as a HeatMap layer
heat_data1 = [[row['from_latitude'], row['from_longitude'], row['trip_count']] for index, row in trip_counts1.iterrows()]
HeatMap(heat_data1).add_to(m1)

# %%
# Save the map as an HTML file and display it
m1.save("divvy_trip_heatmap(from_station).html")

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_
.0], [41.779835, -87.634774, 45.0], [41.77987, -87.650919, 15.0], [41.780079633, -87.629746305, 772.0], [41.780080637, -87.615942857, 605.0], [41.780405646, -87.591415989, 2513.0], [41.780595, -87.584846, 225.0], [41.780599015, -87.606112388, 2839.0], [41.781016372, -87.57611976, 5438.0], [41.783189, -87.654372, 26.0], [41.783681, -87.674101, 17.0], [41.784141693, -87.61330783, 757.0], [41.785097146, -87.601072761, 27558.0], [41.78602, -87.674167, 101.0], [41.786691, -87.655859, 8.0], [41.786833, -87.666215, 115.0], [41.787539, -87.644874, 109.0], [41.787942813, -87.58831517, 11396.0], [41.788746, -87.601334, 30216.0], [41.791478, -87.599861, 46985.0], [41.791568011, -87.607852177, 3357.0], [41.79172821, -87.583945009, 18686.0], [41.792822, -87.664429, 162.0], [41.792929646, -87.644990056, 381.0], [41.793242, -87.587782, 26182.0], [41.793429457, -87.615853262, 1072.0], [41.794087, -87.675478, 52.0], [41.794228, -87.655073, 327.0], [41.794300621, -87.601449773, 31206.0], [41.794354, -87.619304, 69.0], [41.794587, -87.674254, 9.0], [41.794694, -87.654947, 38.0], [41.794853, -87.618691, 8853.0], [41.794982, -87.633124, 1607.0], [41.795212, -87.580715, 40240.0], [41.795264, -87.596471, 19835.0], [41.796642, -87.625923, 106.0], [41.799336263, -87.600958114, 17442.0], [41.799494294, -87.586449896, 18948.0], [41.799568, -87.594747, 36635.0], [41.799659, -87.657195, 93.0], [41.800908, -87.674684, 241.0], [41.80183164, -87.645213904, 180.0], [41.802294651, -87.61805358, 2592.0], [41.802406, -87.586924, 25521.0], [41.802562, -87.590368, 16864.0], [41.803023, -87.664699, 255.0], [41.803038, -87.606615, 4188.0], [41.805661, -87.683392, 740.0], [41.805772, -87.592464, 3800.0], [41.808133915, -87.645616554, 1406.0], [41.808227, -87.67718, 607.0], [41.80839, -87.656526, 357.0], [41.80887, -87.66454, 1369.0], [41.809317709, -87.633449288, 1403.0], [41.809443, -87.591875, 14959.0], [41.809835, -87.59

# %%
# Group the data by starting station latitude and longitude and count the number of trips
trip_counts2 = df.groupby(['to_latitude', 'to_longitude']).size().reset_index(name='trip_count')

# Display the top 5 rows of the aggregated data
print(trip_counts2.head())
# Out:
#    to_latitude  to_longitude  trip_count
# 0    41.736646    -87.622634         304
# 1    41.743116    -87.614800         414
# 2    41.743316    -87.622849         177
# 3    41.743441    -87.604836          76
# 4    41.743921    -87.575225         103

# %%
# Create a base map centered on Chicago (assuming Divvy is Chicago-based)
m2 = folium.Map(location=[41.8781, -87.6298], zoom_start=12)

# Add the trip count as a HeatMap layer
heat_data2 = [[row['to_latitude'], row['to_longitude'], row['trip_count']] for index, row in trip_counts2.iterrows()]
HeatMap(heat_data2).add_to(m2)

# %%
# Save the map as an HTML file and display it
m2.save("divvy_trip_heatmap (to_station).html")

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf8a21d5006c7683a739a8175a7a0e6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf8a21d5006c7683a739a8175a7a0e6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_
0], [41.786691, -87.655859, 13.0], [41.786833, -87.666215, 104.0], [41.787539, -87.644874, 96.0], [41.787942813, -87.58831517, 10151.0], [41.788746, -87.601334, 30704.0], [41.791478, -87.599861, 47773.0], [41.791568011, -87.607852177, 3068.0], [41.79172821, -87.583945009, 18443.0], [41.792822, -87.664429, 160.0], [41.792929646, -87.644990056, 363.0], [41.793242, -87.587782, 27139.0], [41.793429457, -87.615853262, 934.0], [41.794087, -87.675478, 59.0], [41.794228, -87.655073, 331.0], [41.794300621, -87.601449773, 30689.0], [41.794354, -87.619304, 66.0], [41.794587, -87.674254, 6.0], [41.794694, -87.654947, 40.0], [41.794853, -87.618691, 8339.0], [41.794982, -87.633124, 1496.0], [41.795212, -87.580715, 41304.0], [41.795264, -87.596471, 18835.0], [41.796642, -87.625923, 88.0], [41.799336263, -87.600958114, 16985.0], [41.799494294, -87.586449896, 19651.0], [41.799568, -87.594747, 37311.0], [41.799659, -87.657195, 82.0], [41.800908, -87.674684, 363.0], [41.80183164, -87.645213904, 191.0], [41.802294651, -87.61805358, 2527.0], [41.802406, -87.586924, 24592.0], [41.802562, -87.590368, 15486.0], [41.803023, -87.664699, 289.0], [41.803038, -87.606615, 4024.0], [41.805661, -87.683392, 549.0], [41.805772, -87.592464, 3659.0], [41.808133915, -87.645616554, 1511.0], [41.808227, -87.67718, 783.0], [41.80839, -87.656526, 364.0], [41.80887, -87.66454, 1169.0], [41.809317709, -87.633449288, 930.0], [41.809443, -87.591875, 15905.0], [41.809835, -87.59

# %% [markdown]
# ## 04. Key Questions & Answers

# %% [markdown]
# ### 1. Which Stations Are the Most and Least Popular?

# %%
# Count trips starting from each station (from_station_name)
start_station_counts = df['from_station_name'].value_counts().reset_index()
start_station_counts.columns = ['station', 'trip_starts']

# Count trips ending at each station (to_station_name)
end_station_counts = df['to_station_name'].value_counts().reset_index()
end_station_counts.columns = ['station', 'trip_ends']

# Merge the start and end counts
station_popularity = pd.merge(start_station_counts, end_station_counts, on='station', how='outer').fillna(0)

# Calculate total trips per station
station_popularity['total_trips'] = station_popularity['trip_starts'] + station_popularity['trip_ends']

# Sort to find most and least popular stations
most_popular_station = station_popularity.sort_values(by='total_trips', ascending=False).head(5)
least_popular_station = station_popularity.sort_values(by='total_trips', ascending=True).head(5)

print("Most popular station:\n", most_popular_station)
print("Least popular station:\n", least_popular_station)
# Out:
# Most popular station:
#                            station  trip_starts  trip_ends  total_trips
# 647       Streeter Dr & Grand Ave       322483     365427       687910
# 381     Lake Shore Dr & Monroe St       296184     273658       569842
# 173  Clinton St & Washington Blvd       285063     280581       565644
# 96            Canal St & Adams St       274589     264674       539263
# 650           Theater on the Lake       248878     267744       516622
# Least popular station:
#                              station  trip_starts  trip_ends  total_trips
# 206       Damen Ave & Garfield Blvd            7          6           13
# 519          Phillips Ave & 82nd St            5         10           15
# 246          Elizabeth St & 59th St            8         13           21
# 604  South Chicago Ave & Elliot Ave           12         10           22
# 461          Michigan Ave & 71st St           12         16           28

# %% [markdown]
# ### 2. Are There Station Imbalances (More Starts Than Ends)?

# %%
# Calculate imbalance between trip starts and ends
station_popularity['imbalance'] = station_popularity['trip_starts'] - station_popularity['trip_ends']

# Find stations with the largest imbalances (more starts than ends)
imbalanced_stations = station_popularity[station_popularity['imbalance'] != 0].sort_values(by='imbalance', ascending=False)

print("Stations with more starts than ends:\n", imbalanced_stations.head(5))
print("Stations with more ends than starts:\n", imbalanced_stations.tail(5))
# Out:
# Stations with more starts than ends:
#                            station  trip_starts  trip_ends  total_trips  \
# 175     Columbus Dr & Randolph St       198532     129028       327560
# 381     Lake Shore Dr & Monroe St       296184     273658       569842
# 638  Stetson Ave & South Water St        79810      63883       143693
# 100          Canal St & Monroe St        44524      28753        73277
# 281       Franklin St & Monroe St       143796     128843       272639
#
#      imbalance
# 175      69504
# 381      22526
# 638      15927
# 100      15771
# 281      14953
# Stations with more ends than starts:
#                          station  trip_starts  trip_ends  total_trips  \
# 619      St. Clair St & Erie St       101097     122308       223405
# 475             Millennium Park       224894     247904       472798
# 648   Streeter Dr & Illinois St       137666     164081       301747
# 382  Lake Shore Dr & North Blvd       231508     263770       495278
# 647     Streeter Dr & Grand Ave       322483     365427       687910
#
#      imbalance
# 619     -21211
# 475     -23010
# 648     -26415
# 382     -32262
# 647     -42944

# %% [markdown]
# ### 3. Are There Underserved Areas with Fewer Stations?

# %%
# Create a map centered on Chicago
m = folium.Map(location=[41.8781, -87.6298], zoom_start=12)

# Add starting station locations to the map
for index, row in df[['from_latitude', 'from_longitude', 'from_station_name']].drop_duplicates().iterrows():
    folium.Marker([row['from_latitude'], row['from_longitude']], popup=row['from_station_name']).add_to(m)

# Save the map as an HTML file
m.save("station_map.html")

# Display the map (if running in Jupyter notebook)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_587f2459aca1625c752ccd09a8596fc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_587f2459aca1625c752ccd09a8596fc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_587f2459aca1625c752ccd09a8596fc5 = L.map(
#                 &quot;map_587f2459aca1625c752ccd09a8596fc5&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c316aff73912e44a9062202b2ae1aa2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4c316aff73912e44a9062202b2ae1aa2.addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#             var marker_50671c90bb329f7f9838d7d651ceacd6 = L.marker(
#                 [41.94018, -87.65304],
#                 {}
#             ).addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#         var popup_466b839eb186b50993a92cba8ad9bbc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_314d3189c6a0998f87e888f2f3aa73fe = $(`&lt;div id=&quot;html_314d3189c6a0998f87e888f2f3aa73fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wilton Ave &amp; Belmont Ave&lt;/div&gt;`)[0];
#                 popup_466b839eb186b50993a92cba8ad9bbc1.setContent(html_314d3189c6a0998f87e888f2f3aa73fe);
#
#
#
#         marker_50671c90bb329f7f9838d7d651ceacd6.bindPopup(popup_466b839eb186b50993a92cba8ad9bbc1)
#         ;
#
#
#
#
#             var marker_49573052e3864541edf1aa7529da3027 = L.marker(
#                 [41.907993, -87.631501],
#                 {}
#             ).addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#         var popup_e7409d031b44c3e2da5fe5e78e7ffa23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b6d99a95b0e7b988885815ea8a1603b = $(`&lt;div id=&quot;html_5b6d99a95b0e7b988885815ea8a1603b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clark St &amp; Schiller St&lt;/div&gt;`)[0];
#                 popup_e7409d031b44c3e2da5fe5e78e7ffa23.setContent(html_5b6d99a95b0e7b988885815ea8a1603b);
#
#
#
#         marker_49573052e3864541edf1aa7529da3027.bindPopup(popup_e7409d031b44c3e2da5fe5e78e7ffa23)
#         ;
#
#
#
#
#             var marker_584a6b5ace84481883e74fd30e3acda4 = L.marker(
#                 [41.9716, -87.650154],
#                 {}
#             ).addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#         var popup_afd48f85c16e37e08b03bc3d4437e0cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6f6072dc29b3b52a9a317a5aa1cf870 = $(`&lt;div id=&quot;html_f6f6072dc29b3b52a9a317a5aa1cf870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marine Dr &amp; Ainslie St&lt;/div&gt;`)[0];
#                 popup_afd48f85c16e37e08b03bc3d4437e0cc.setContent(html_f6f6072dc29b3b52a9a317a5aa1cf870);
#
#
#
#         marker_584a6b5ace84481883e74fd30e3acda4.bindPopup(popup_afd48f85c16e37e08b03bc3d4437e0cc)
#         ;
#
#
#
#
#             var marker_5ccb6c7c3ae53c9a0e58909c6e2c5ff3 = L.marker(
#                 [41.907066, -87.667252],
#                 {}
#             ).addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#         var popup_459b012686b218873facec97ede2cac5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aee71d6159f03257668d7f0e4144dc71 = $(`&lt;div id=&quot;html_aee71d6159f03257668d7f0e4144dc71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ashland Ave &amp; Blackhawk St&lt;/div&gt;`)[0];
#                 popup_459b012686b218873facec97ede2cac5.setContent(html_aee71d6159f03257668d7f0e4144dc71);
#
#
#
#         marker_5ccb6c7c3ae53c9a0e58909c6e2c5ff3.bindPopup(popup_459b012686b218873facec97ede2cac5)
#         ;
#
#
#
#
#             var marker_9f8a798f8ad561a8aa02b6b2d766d3eb = L.marker(
#                 [41.897764, -87.642884],
#                 {}
#             ).addTo(map_587f2459aca1625c752ccd09a8596fc5);
#
#
#         var popup_2b9099b378196fef1e79223a57b241cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b068e22bd29d83f26175232ce995361 = $(`&lt;div id=&quot;html_2b068e22bd29d83f26175232ce995361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Larrabee St &amp; Kingsbury St&lt;/div&gt;`)[0];
#                 popup_2b9099b378196fef1e79223a57b241cd.setContent(html_2b068e22bd29d83f26175232ce995361);
#
#
#
#         marker_9f8a798f8ad561a8aa02b6b2d766d3eb.bindPopup(popup_2b9099b378196fef1e79223a57b241cd)
#         ;
#
#
#
#
#             var marker_cb598bfba78ca00da0231c7ce606bc48 = L.marker(
#                 [41.8378, -87.65114],

# %% [markdown]
# ## Note:
# #### From the density map, it can be concluded that most of the stations are located near the city center and along the coastal areas.
